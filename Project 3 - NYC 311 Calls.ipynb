# %% [markdown]
# # Project 3 – NYC 311 calls

# %% [markdown]
# NYC 311 is a service that provides access to non-emergency City services and info about City government programs to the residents of New York.  Each year, the service receives millions of requests reporting various kinds of problems with city services and other issues.
#
# The data on the type of calls received, and their ultimate resolution is made available through the NYC Open Data portal at https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9. The data is updated daily.  The link also provides the data dictionary for the data.
#
# To ensure that we are all using the same data and arrive at the same results, the data has been downloaded and includes information up to 2023-08-04 12:00:00.  Several columns not required for this project have been removed from the original data.  (As an additional exercise to showcase your skills, you should feel free to download the entire dataset from the URL above for investigation.)
#
# Please use the Project-3_NYC_311_Calls.pkl for this analysis.  The data file is available as a pickle file on Jupyterhub, and has information on 32 million calls to 311.  You should be able to read the file into a dataframe using pd.read_pickle('Project-3_NYC_311_Calls.pkl')
#
# You may choose to move the ‘Created Date’ to the dataframe’s index, for example, using the below code.
#
# '''
# We make the index as a proper DatetimeIndex, and then delete the Created Date column
# '''
#
#
# df = df.set_index(pd.DatetimeIndex(df['Created Date']))
#
# del df['Created Date']

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_pickle('shared/Project-3_NYC_311_Calls.pkl')

# %%
# We make the index as a proper DatetimeIndex, and then delete the Created Date column
df = df.set_index(pd.DatetimeIndex(df['Created Date']))
del df['Created Date']
df
# Out:
#                      Unique Key Agency  \
# Created Date
# 2011-04-06 00:00:00    20184537    HPD
# 2011-04-06 00:00:00    20184538    HPD
# 2011-04-06 00:00:00    20184539    HPD
# 2022-07-08 11:14:43    54732265   DSNY
# 2011-04-06 00:00:00    20184540    HPD
# ...                         ...    ...
# 2011-04-06 00:00:00    20184532    HPD
# 2011-04-06 00:00:00    20184533    HPD
# 2011-04-06 00:00:00    20184534    HPD
# 2011-04-06 00:00:00    20184535    HPD
# 2011-04-06 00:00:00    20184536    HPD
#
#                                                            Agency Name  \
# Created Date
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2022-07-08 11:14:43                           Department of Sanitation
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# ...                                                                ...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
# 2011-04-06 00:00:00  Department of Housing Preservation and Develop...
#
#                            Complaint Type   Descriptor         Location Type  \
# Created Date
# 2011-04-06 00:00:00               HEATING         HEAT  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00  GENERAL CONSTRUCTION      WINDOWS  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00       PAINT - PLASTER        WALLS  RESIDENTIAL BUILDING
# 2022-07-08 11:14:43       Dirty Condition        Trash              Sidewalk
# 2011-04-06 00:00:00              NONCONST       VERMIN  RESIDENTIAL BUILDING
# ...                                   ...          ...                   ...
# 2011-04-06 00:00:00               HEATING         HEAT  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00               HEATING         HEAT  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00  GENERAL CONSTRUCTION       STAIRS  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00  GENERAL CONSTRUCTION          GAS  RESIDENTIAL BUILDING
# 2011-04-06 00:00:00              PLUMBING  WATER-LEAKS  RESIDENTIAL BUILDING
#
#                     Incident Zip      City  \
# Created Date
# 2011-04-06 00:00:00      10002.0  NEW YORK
# 2011-04-06 00:00:00      11236.0  BROOKLYN
# 2011-04-06 00:00:00      10460.0     BRONX
# 2022-07-08 11:14:43      10467.0     BRONX
# 2011-04-06 00:00:00      10460.0     BRONX
# ...                          ...       ...
# 2011-04-06 00:00:00        10468     BRONX
# 2011-04-06 00:00:00        10018  NEW YORK
# 2011-04-06 00:00:00        10460     BRONX
# 2011-04-06 00:00:00        11236  BROOKLYN
# 2011-04-06 00:00:00        11236  BROOKLYN
#
#                                                 Resolution Description  \
# Created Date
# 2011-04-06 00:00:00  More than one complaint was received for this ...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# 2022-07-08 11:14:43  The Department of Sanitation investigated this...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# ...                                                                ...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# 2011-04-06 00:00:00  More than one complaint was received for this ...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
# 2011-04-06 00:00:00  The Department of Housing Preservation and Dev...
#
#                        Borough Open Data Channel Type
# Created Date
# 2011-04-06 00:00:00  MANHATTAN                UNKNOWN
# 2011-04-06 00:00:00   BROOKLYN                UNKNOWN
# 2011-04-06 00:00:00      BRONX                UNKNOWN
# 2022-07-08 11:14:43      BRONX                  PHONE
# 2011-04-06 00:00:00      BRONX                UNKNOWN
# ...                        ...                    ...
# 2011-04-06 00:00:00      BRONX                UNKNOWN
# 2011-04-06 00:00:00  MANHATTAN                UNKNOWN
# 2011-04-06 00:00:00      BRONX                UNKNOWN
# 2011-04-06 00:00:00   BROOKLYN                UNKNOWN
# 2011-04-06 00:00:00   BROOKLYN                UNKNOWN
#
# [33780977 rows x 11 columns]

# %% [markdown]
# ## Data Exploration
#
# Spend some time querying the data, and making yourself familiar with it using the EDA techniques we learned in class.  Show your EDA in the Jupyter notebook you will use for uploading to Github.  Look at the types of complaints, read some descriptions, see the earliest date, the latest date etc.  Read the data dictionary to understand what the columns mean.  Be aware that many columns have NaN values, and they may not get counted for your analysis.

# %%
# Basic Information about the Dataset
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 33780977 entries, 2011-04-06 00:00:00 to 2011-04-06 00:00:00
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unique Key              int64
#  1   Agency                  object
#  2   Agency Name             object
#  3   Complaint Type          object
#  4   Descriptor              object
#  5   Location Type           object
#  6   Incident Zip            object
#  7   City                    object
#  8   Resolution Description  object
#  9   Borough                 object
#  10  Open Data Channel Type  object
# dtypes: int64(1), object(10)
# memory usage: 3.0+ GB
# None

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Unique Key                      0
# Agency                          0
# Agency Name                     0
# Complaint Type                  0
# Descriptor                 586677
# Location Type             7140574
# Incident Zip              1507958
# City                      1981664
# Resolution Description    1254890
# Borough                     47074
# Open Data Channel Type          0
# dtype: int64

# %%
df_unique_key = df['Unique Key'].resample(rule='D').count()
df_unique_key
# Out:
# Created Date
# 2010-01-01    2942
# 2010-01-02    3958
# 2010-01-03    5676
# 2010-01-04    9763
# 2010-01-05    8735
#               ...
# 2023-07-31    9921
# 2023-08-01    9813
# 2023-08-02    9245
# 2023-08-03    9128
# 2023-08-04     384
# Freq: D, Name: Unique Key, Length: 4964, dtype: int64

# %%
# On which single date were the maximum number of calls received?
print('single date were the maximum number of calls received:',df_unique_key.idxmax())
print('maximum number:',df_unique_key.max())
# Out:
# single date were the maximum number of calls received: 2020-08-04 00:00:00
# maximum number: 24415

# %%
# On the date the maximum number of calls were received, what was the most important complaint type?
max_calls_date_data = df.loc['2020-08-04']
max_calls_date_data
# Out:
#                      Unique Key Agency                         Agency Name  \
# Created Date
# 2020-08-04 20:26:03    47103795    DPR  Department of Parks and Recreation
# 2020-08-04 20:02:44    47107936    DPR  Department of Parks and Recreation
# 2020-08-04 15:35:00    47098354    DOT        Department of Transportation
# 2020-08-04 11:52:00    47105987    DOT        Department of Transportation
# 2020-08-04 12:00:00    47118929   DSNY            Department of Sanitation
# ...                         ...    ...                                 ...
# 2020-08-04 18:22:59    47107565    DPR  Department of Parks and Recreation
# 2020-08-04 13:05:56    47145515    DOT        Department of Transportation
# 2020-08-04 12:06:58    47089692    DPR  Department of Parks and Recreation
# 2020-08-04 15:10:35    47096612    DPR  Department of Parks and Recreation
# 2020-08-04 19:42:33    47103122    DPR  Department of Parks and Recreation
#
#                                Complaint Type                      Descriptor  \
# Created Date
# 2020-08-04 20:26:03              Damaged Tree     Entire Tree Has Fallen Down
# 2020-08-04 20:02:44              Damaged Tree     Entire Tree Has Fallen Down
# 2020-08-04 15:35:00  Traffic Signal Condition                  Vehicle Signal
# 2020-08-04 11:52:00    Street Light Condition                Street Light Out
# 2020-08-04 12:00:00         Derelict Vehicles               Derelict Vehicles
# ...                                       ...                             ...
# 2020-08-04 18:22:59              Damaged Tree  Branch or Limb Has Fallen Down
# 2020-08-04 13:05:56          Street Condition                         Pothole
# 2020-08-04 12:06:58              Damaged Tree  Branch or Limb Has Fallen Down
# 2020-08-04 15:10:35              Damaged Tree     Entire Tree Has Fallen Down
# 2020-08-04 19:42:33              Damaged Tree     Entire Tree Has Fallen Down
#
#                     Location Type Incident Zip   City  \
# Created Date
# 2020-08-04 20:26:03        Street          NaN    NaN
# 2020-08-04 20:02:44        Street          NaN    NaN
# 2020-08-04 15:35:00           NaN          NaN    NaN
# 2020-08-04 11:52:00           NaN          NaN    NaN
# 2020-08-04 12:00:00        Street          NaN    NaN
# ...                           ...          ...    ...
# 2020-08-04 18:22:59        Street          NaN    NaN
# 2020-08-04 13:05:56           NaN        10467  BRONX
# 2020-08-04 12:06:58        Street          NaN    NaN
# 2020-08-04 15:10:35        Street          NaN    NaN
# 2020-08-04 19:42:33        Street          NaN    NaN
#
#                                                 Resolution Description  \
# Created Date
# 2020-08-04 20:26:03  The Department of Parks and Recreation visited...
# 2020-08-04 20:02:44  The Department of Parks and Recreation has ins...
# 2020-08-04 15:35:00  Service Request status for this request is ava...
# 2020-08-04 11:52:00  Service Request status for this request is ava...
# 2020-08-04 12:00:00  The Department of Sanitation Investigated and ...
# ...                                                                ...
# 2020-08-04 18:22:59  The Department of Parks and Recreation perform...
# 2020-08-04 13:05:56  The Department of Transportation inspected thi...
# 2020-08-04 12:06:58  The Department of Parks and Recreation perform...
# 2020-08-04 15:10:35  The Department of Parks and Recreation visited...
# 2020-08-04 19:42:33  The Department of Parks and Recreation perform...
#
#                          Borough Open Data Channel Type
# Created Date
# 2020-08-04 20:26:03  Unspecified                UNKNOWN
# 2020-08-04 20:02:44  Unspecified                UNKNOWN
# 2020-08-04 15:35:00          NaN                UNKNOWN
# 2020-08-04 11:52:00       QUEENS                UNKNOWN
# 2020-08-04 12:00:00          NaN                  PHONE
# ...                          ...                    ...
# 2020-08-04 18:22:59  Unspecified                UNKNOWN
# 2020-08-04 13:05:56        BRONX                UNKNOWN
# 2020-08-04 12:06:58  Unspecified                UNKNOWN
# 2020-08-04 15:10:35  Unspecified                UNKNOWN
# 2020-08-04 19:42:33  Unspecified                UNKNOWN
#
# [24415 rows x 11 columns]

# %%
# Count the occurrences of each complaint type on that date
complaint_type_counts = max_calls_date_data['Complaint Type'].value_counts()
complaint_type_counts
# Out:
# Complaint Type
# Damaged Tree                           14863
# Noise - Residential                      982
# Request Large Bulky Item Collection      909
# Street Light Condition                   617
# Overgrown Tree/Branches                  609
#                                        ...
# Bus Stop Shelter Placement                 1
# Unsanitary Pigeon Condition                1
# Public Payphone Complaint                  1
# For Hire Vehicle Report                    1
# Bridge Condition                           1
# Name: count, Length: 125, dtype: int64

# %%
# Quietest month: Group the data by months, and identify the month that historically has the fewest number of calls.
df_quite_month = df.groupby(df.index.month).size()
df_quite_month
# Out:
# Created Date
# 1     2994507
# 2     2621845
# 3     2868044
# 4     2672760
# 5     2956598
# 6     3093442
# 7     3111026
# 8     2779862
# 9     2684271
# 10    2766887
# 11    2634749
# 12    2596986
# dtype: int64

# %%
print('Quiet month:',df_quite_month.idxmin())
# Out:
# Quiet month: 12

# %%
df_2022 = df[(df.index > pd.to_datetime('1/1/2022')) & (df.index < pd.to_datetime('1/1/2023'))]
df_2022
# Out:
#                      Unique Key Agency  \
# Created Date
# 2022-07-08 11:14:43    54732265   DSNY
# 2022-07-08 12:07:45    54732266   DSNY
# 2022-07-08 06:06:47    54732267   DSNY
# 2022-07-08 14:12:01    54732268   DSNY
# 2022-07-08 11:25:58    54732269   DSNY
# ...                         ...    ...
# 2022-08-28 14:10:00    55237319    DEP
# 2022-11-21 16:06:35    56051500    HPD
# 2022-07-08 18:18:10    54732262   DSNY
# 2022-07-08 07:51:59    54732263   DSNY
# 2022-07-08 23:31:31    54732264   DSNY
#
#                                                            Agency Name  \
# Created Date
# 2022-07-08 11:14:43                           Department of Sanitation
# 2022-07-08 12:07:45                           Department of Sanitation
# 2022-07-08 06:06:47                           Department of Sanitation
# 2022-07-08 14:12:01                           Department of Sanitation
# 2022-07-08 11:25:58                           Department of Sanitation
# ...                                                                ...
# 2022-08-28 14:10:00             Department of Environmental Protection
# 2022-11-21 16:06:35  Department of Housing Preservation and Develop...
# 2022-07-08 18:18:10                           Department of Sanitation
# 2022-07-08 07:51:59                           Department of Sanitation
# 2022-07-08 23:31:31                           Department of Sanitation
#
#                       Complaint Type                          Descriptor  \
# Created Date
# 2022-07-08 11:14:43  Dirty Condition                               Trash
# 2022-07-08 12:07:45  Dirty Condition                               Trash
# 2022-07-08 06:06:47  Dirty Condition                               Trash
# 2022-07-08 14:12:01  Dirty Condition                               Trash
# 2022-07-08 11:25:58  Dirty Condition                               Trash
# ...                              ...                                 ...
# 2022-08-28 14:10:00            Sewer  Defective/Missing Curb Piece (SC4)
# 2022-11-21 16:06:35        APPLIANCE                        REFRIGERATOR
# 2022-07-08 18:18:10  Dirty Condition                               Trash
# 2022-07-08 07:51:59  Dirty Condition                               Trash
# 2022-07-08 23:31:31  Dirty Condition                               Trash
#
#                             Location Type Incident Zip          City  \
# Created Date
# 2022-07-08 11:14:43              Sidewalk      10467.0         BRONX
# 2022-07-08 12:07:45              Sidewalk      10009.0      NEW YORK
# 2022-07-08 06:06:47              Sidewalk      11204.0      BROOKLYN
# 2022-07-08 14:12:01              Sidewalk      10455.0         BRONX
# 2022-07-08 11:25:58              Sidewalk      10025.0      NEW YORK
# ...                                   ...          ...           ...
# 2022-08-28 14:10:00                   NaN        11691  FAR ROCKAWAY
# 2022-11-21 16:06:35  RESIDENTIAL BUILDING        11238      BROOKLYN
# 2022-07-08 18:18:10              Sidewalk        10468         BRONX
# 2022-07-08 07:51:59              Sidewalk        10027      NEW YORK
# 2022-07-08 23:31:31              Sidewalk        11207      BROOKLYN
#
#                                                 Resolution Description  \
# Created Date
# 2022-07-08 11:14:43  The Department of Sanitation investigated this...
# 2022-07-08 12:07:45  The Department of Sanitation investigated this...
# 2022-07-08 06:06:47  The Department of Sanitation investigated this...
# 2022-07-08 14:12:01  The Department of Sanitation investigated this...
# 2022-07-08 11:25:58  The Department of Sanitation investigated this...
# ...                                                                ...
# 2022-08-28 14:10:00  The Department of Environmental Protection inv...
# 2022-11-21 16:06:35  The Department of Housing Preservation and Dev...
# 2022-07-08 18:18:10  The Department of Sanitation investigated this...
# 2022-07-08 07:51:59  The Department of Sanitation investigated this...
# 2022-07-08 23:31:31  The Department of Sanitation investigated this...
#
#                        Borough Open Data Channel Type
# Created Date
# 2022-07-08 11:14:43      BRONX                  PHONE
# 2022-07-08 12:07:45  MANHATTAN                 MOBILE
# 2022-07-08 06:06:47   BROOKLYN                 MOBILE
# 2022-07-08 14:12:01      BRONX                 MOBILE
# 2022-07-08 11:25:58  MANHATTAN                  PHONE
# ...                        ...                    ...
# 2022-08-28 14:10:00     QUEENS                  PHONE
# 2022-11-21 16:06:35   BROOKLYN                  PHONE
# 2022-07-08 18:18:10      BRONX                 MOBILE
# 2022-07-08 07:51:59  MANHATTAN                 MOBILE
# 2022-07-08 23:31:31   BROOKLYN                 MOBILE
#
# [3169776 rows x 11 columns]

# %%
# What is the average number of daily complaints received in 2022?
df_2022_daily = df_2022.resample(rule='D')['Unique Key'].count()
df_2022_daily
# Out:
# Created Date
# 2022-01-01     5865
# 2022-01-02     6710
# 2022-01-03     9163
# 2022-01-04     9415
# 2022-01-05     8385
#               ...
# 2022-12-27    10250
# 2022-12-28     9036
# 2022-12-29     8279
# 2022-12-30     7582
# 2022-12-31     5742
# Freq: D, Name: Unique Key, Length: 365, dtype: int64

# %%
df_2022_daily.mean()
# Out:
# 8684.317808219179

# %%
# Now we decompose our time series

import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

df2 = df.iloc[:,:1]
df2
# Out:
#                      Unique Key
# Created Date
# 2011-04-06 00:00:00    20184537
# 2011-04-06 00:00:00    20184538
# 2011-04-06 00:00:00    20184539
# 2022-07-08 11:14:43    54732265
# 2011-04-06 00:00:00    20184540
# ...                         ...
# 2011-04-06 00:00:00    20184532
# 2011-04-06 00:00:00    20184533
# 2011-04-06 00:00:00    20184534
# 2011-04-06 00:00:00    20184535
# 2011-04-06 00:00:00    20184536
#
# [33780977 rows x 1 columns]

# %%
daily_call = df2.resample(rule='D')['Unique Key'].count()
daily_call = daily_call.reset_index(name='Total Calls')
daily_call = daily_call.set_index('Created Date')
daily_call
# Out:
#               Total Calls
# Created Date
# 2010-01-01           2942
# 2010-01-02           3958
# 2010-01-03           5676
# 2010-01-04           9763
# 2010-01-05           8735
# ...                   ...
# 2023-07-31           9921
# 2023-08-01           9813
# 2023-08-02           9245
# 2023-08-03           9128
# 2023-08-04            384
#
# [4964 rows x 1 columns]

# %%
# We use the ETS additive model
result = seasonal_decompose(daily_call['Total Calls'], model = 'additive')

# %%
ets = pd.DataFrame({'Total Calls':daily_call['Total Calls'],
                    'trend': result.trend,
                    'seasonality': result.seasonal,
                    'error': result.resid})
ets.loc['2020-12-25','seasonality']
# Out:
# 182.69763790386236

# %%
# Calculate the autocorrelation of the number of daily calls with the number of calls the day prior, ie lag of 1.  (Use the daily series).
daily_call['Total Calls'].autocorr(lag = 1)
# Out:
# 0.7517059728398577

# %%
# Forecast the daily series with a test set of 90 days using the Prophet library.  What is your RMSE on your test set?
from prophet import Prophet
daily_call = pd.DataFrame(daily_call)
daily_call = daily_call.reset_index()
daily_call
# Out:
#      Created Date  Total Calls
# 0      2010-01-01         2942
# 1      2010-01-02         3958
# 2      2010-01-03         5676
# 3      2010-01-04         9763
# 4      2010-01-05         8735
# ...           ...          ...
# 4959   2023-07-31         9921
# 4960   2023-08-01         9813
# 4961   2023-08-02         9245
# 4962   2023-08-03         9128
# 4963   2023-08-04          384
#
# [4964 rows x 2 columns]

# %%
# Train-test split

train_set = daily_call.iloc[:-90]
test_set = daily_call.iloc[-90:]

print("Training set: ", train_set.shape[0])
print("Test set: ", test_set.shape[0])
# Out:
# Training set:  4874
# Test set:  90

# %%
# Create the ds and y columns for Prophet
train_set_prophet = train_set.reset_index()
train_set_prophet = train_set_prophet[['Created Date', 'Total Calls']]
train_set_prophet.columns = ['ds', 'y']
train_set_prophet.head()
# Out:
#           ds     y
# 0 2010-01-01  2942
# 1 2010-01-02  3958
# 2 2010-01-03  5676
# 3 2010-01-04  9763
# 4 2010-01-05  8735

# %%
model = Prophet()
model.fit(train_set_prophet)
# Out:
# 21:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 21:28:46 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=90,freq = 'd')
future.tail()
# Out:
#              ds
# 4959 2023-07-31
# 4960 2023-08-01
# 4961 2023-08-02
# 4962 2023-08-03
# 4963 2023-08-04

# %%
future.shape
# Out:
# (4964, 1)

# %%
# Python
forecast = model.predict(future)
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'weekly', 'weekly_lower', 'weekly_upper', 'yearly', 'yearly_lower',
#        'yearly_upper', 'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
preds = pd.DataFrame({'Prediction': forecast.yhat[-90:]})
preds.index = pd.to_datetime(forecast.ds[-90:])
preds.index.names = ['Date']
preds
# Out:
#              Prediction
# Date
# 2023-05-07  7242.556928
# 2023-05-08  9229.604309
# 2023-05-09  9291.220112
# 2023-05-10  9131.293129
# 2023-05-11  8981.995534
# ...                 ...
# 2023-07-31  9588.156716
# 2023-08-01  9636.185749
# 2023-08-02  9462.665714
# 2023-08-03  9299.547111
# 2023-08-04  9081.926149
#
# [90 rows x 1 columns]

# %%
# Calculate Evaluation Metrics

y_test = test_set['Total Calls'] 
y_pred = preds['Prediction']
pd.DataFrame({'y_test': y_test, 'y_pred' : y_pred, 'diff':y_test - y_pred})
# Out:
# /tmp/ipykernel_318/892524431.py:5: RuntimeWarning: '<' not supported between instances of 'Timestamp' and 'int', sort order is undefined for incomparable objects.
#   pd.DataFrame({'y_test': y_test, 'y_pred' : y_pred, 'diff':y_test - y_pred})
#                      y_test       y_pred  diff
# 4874                 9102.0          NaN   NaN
# 4875                 9709.0          NaN   NaN
# 4876                 9309.0          NaN   NaN
# 4877                 9110.0          NaN   NaN
# 4878                 9155.0          NaN   NaN
# ...                     ...          ...   ...
# 2023-07-31 00:00:00     NaN  9588.156716   NaN
# 2023-08-01 00:00:00     NaN  9636.185749   NaN
# 2023-08-02 00:00:00     NaN  9462.665714   NaN
# 2023-08-03 00:00:00     NaN  9299.547111   NaN
# 2023-08-04 00:00:00     NaN  9081.926149   NaN
#
# [180 rows x 3 columns]

# %%
# Model evaluation

from sklearn.metrics import mean_absolute_error, mean_squared_error
print('MSE = ', mean_squared_error(y_test,y_pred))
print('RMSE = ', np.sqrt(mean_squared_error(y_test,y_pred)))
print('MAE = ', mean_absolute_error(y_test,y_pred))
# Out:
# MSE =  1516626.1429373787
# RMSE =  1231.513760758433
# MAE =  692.2150947529236
